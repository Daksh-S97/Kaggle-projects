# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fifa19/data.csv

# %%
data = pd.read_csv('../input/fifa19/data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.set_index(data['ID'], inplace=True)

# %%
data.head()
# Out:
#         Unnamed: 0      ID               Name  Age  \
# ID
# 158023           0  158023           L. Messi   31
# 20801            1   20801  Cristiano Ronaldo   33
# 190871           2  190871          Neymar Jr   26
# 193080           3  193080             De Gea   27
# 192985           4  192985       K. De Bruyne   27
#
#                                                  Photo Nationality  \
# ID
# 158023  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 20801    https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 190871  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 193080  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 192985  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                        Flag  Overall  Potential  \
# ID
# 158023  https://cdn.sofifa.org/flags/52.png       94         94
# 20801   https://cdn.sofifa.org/flags/38.png       94         94
# ...

# %%
data.drop(['ID','Photo','Flag'], axis=1,inplace=True)

# %%
data.head()
# Out:
#         Unnamed: 0               Name  Age Nationality  Overall  Potential  \
# ID
# 158023           0           L. Messi   31   Argentina       94         94
# 20801            1  Cristiano Ronaldo   33    Portugal       94         94
# 190871           2          Neymar Jr   26      Brazil       92         93
# 193080           3             De Gea   27       Spain       91         93
# 192985           4       K. De Bruyne   27     Belgium       91         92
#
#                        Club                                     Club Logo  \
# ID
# 158023         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png
# 20801              Juventus   https://cdn.sofifa.org/teams/2/light/45.png
# 190871  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png
# 193080    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png
# 192985      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png
#
# ...

# %%
data.drop(['Club Logo', 'Value', 'Wage', 'Club', 'Overall', 'Potential', 'Nationality'], axis=1, inplace=True)
data.head()
# Out:
#         Unnamed: 0               Name  Age  Special Preferred Foot  \
# ID
# 158023           0           L. Messi   31     2202           Left
# 20801            1  Cristiano Ronaldo   33     2228          Right
# 190871           2          Neymar Jr   26     2143          Right
# 193080           3             De Gea   27     1471          Right
# 192985           4       K. De Bruyne   27     2281          Right
#
#         International Reputation  Weak Foot  Skill Moves       Work Rate  \
# ID
# 158023                       5.0        4.0          4.0  Medium/ Medium
# 20801                        5.0        4.0          5.0       High/ Low
# 190871                       5.0        5.0          5.0    High/ Medium
# 193080                       4.0        3.0          1.0  Medium/ Medium
# 192985                       4.0        5.0          4.0      High/ High
#
#          Body Type  ... Composure Marking  StandingTackle SlidingTackle  \
# ID                  ...
# ...

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data.drop(['Special', 'Body Type'], axis=1, inplace=True)

# %%
data.head()
# Out:
#                      Name  Age Preferred Foot  International Reputation  \
# ID
# 158023           L. Messi   31           Left                       5.0
# 20801   Cristiano Ronaldo   33          Right                       5.0
# 190871          Neymar Jr   26          Right                       5.0
# 193080             De Gea   27          Right                       4.0
# 192985       K. De Bruyne   27          Right                       4.0
#
#         Weak Foot  Skill Moves       Work Rate Real Face Position  \
# ID
# 158023        4.0          4.0  Medium/ Medium       Yes       RF
# 20801         4.0          5.0       High/ Low       Yes       ST
# 190871        5.0          5.0    High/ Medium       Yes       LW
# 193080        3.0          1.0  Medium/ Medium       Yes       GK
# 192985        5.0          4.0      High/ High       Yes      RCM
#
#         Jersey Number  ... Composure Marking StandingTackle SlidingTackle  \
# ID                     ...
# ...

# %%
data.drop(['Jersey Number', 'International Reputation', 'Real Face'], axis=1, inplace=True)
data.head()
# Out:
#                      Name  Age Preferred Foot  Weak Foot  Skill Moves  \
# ID
# 158023           L. Messi   31           Left        4.0          4.0
# 20801   Cristiano Ronaldo   33          Right        4.0          5.0
# 190871          Neymar Jr   26          Right        5.0          5.0
# 193080             De Gea   27          Right        3.0          1.0
# 192985       K. De Bruyne   27          Right        5.0          4.0
#
#              Work Rate Position        Joined Loaned From  \
# ID
# 158023  Medium/ Medium       RF   Jul 1, 2004         NaN
# 20801        High/ Low       ST  Jul 10, 2018         NaN
# 190871    High/ Medium       LW   Aug 3, 2017         NaN
# 193080  Medium/ Medium       GK   Jul 1, 2011         NaN
# 192985      High/ High      RCM  Aug 30, 2015         NaN
#
#        Contract Valid Until  ... Composure Marking StandingTackle  \
# ID                           ...
# 158023                 2021  ...      96.0    33.0           28.0
# ...

# %%
data.drop(['Joined', 'Loaned From', 'Contract Valid Until','Preferred Foot'], axis=1, inplace=True)
data.head()
# Out:
#                      Name  Age  Weak Foot  Skill Moves       Work Rate  \
# ID
# 158023           L. Messi   31        4.0          4.0  Medium/ Medium
# 20801   Cristiano Ronaldo   33        4.0          5.0       High/ Low
# 190871          Neymar Jr   26        5.0          5.0    High/ Medium
# 193080             De Gea   27        3.0          1.0  Medium/ Medium
# 192985       K. De Bruyne   27        5.0          4.0      High/ High
#
#        Position Height  Weight    LS    ST  ... Composure Marking  \
# ID                                          ...
# 158023       RF    5'7  159lbs  88+2  88+2  ...      96.0    33.0
# 20801        ST    6'2  183lbs  91+3  91+3  ...      95.0    28.0
# 190871       LW    5'9  150lbs  84+3  84+3  ...      94.0    27.0
# 193080       GK    6'4  168lbs   NaN   NaN  ...      68.0    15.0
# 192985      RCM   5'11  154lbs  82+3  82+3  ...      88.0    68.0
#
#        StandingTackle SlidingTackle GKDiving GKHandling GKKicking  \
# ID
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Weak Foot', 'Skill Moves', 'Work Rate', 'Position',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
print(data[data['Name']=='Cristiano Ronaldo'][8:34])
# Out:
# Empty DataFrame
# Columns: [Name, Age, Weak Foot, Skill Moves, Work Rate, Position, Height, Weight, LS, ST, RS, LW, LF, CF, RF, RW, LAM, CAM, RAM, LM, LCM, CM, RCM, RM, LWB, LDM, CDM, RDM, RWB, LB, LCB, CB, RCB, RB, Crossing, Finishing, HeadingAccuracy, ShortPassing, Volleys, Dribbling, Curve, FKAccuracy, LongPassing, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Release Clause]
# Index: []
#
# [0 rows x 69 columns]

# %%
data.drop([ 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW','LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM','CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB'], axis=1, inplace=True)
data.head()
# Out:
#                      Name  Age  Weak Foot  Skill Moves       Work Rate  \
# ID
# 158023           L. Messi   31        4.0          4.0  Medium/ Medium
# 20801   Cristiano Ronaldo   33        4.0          5.0       High/ Low
# 190871          Neymar Jr   26        5.0          5.0    High/ Medium
# 193080             De Gea   27        3.0          1.0  Medium/ Medium
# 192985       K. De Bruyne   27        5.0          4.0      High/ High
#
#        Position Height  Weight  Crossing  Finishing  ...  Composure  Marking  \
# ID                                                   ...
# 158023       RF    5'7  159lbs      84.0       95.0  ...       96.0     33.0
# 20801        ST    6'2  183lbs      84.0       94.0  ...       95.0     28.0
# 190871       LW    5'9  150lbs      79.0       87.0  ...       94.0     27.0
# 193080       GK    6'4  168lbs      17.0       13.0  ...       68.0     15.0
# 192985      RCM   5'11  154lbs      93.0       82.0  ...       88.0     68.0
#
# ...

# %%
data.dropna(inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16643 entries, 158023 to 246269
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16643 non-null  object
#  1   Age              16643 non-null  int64
#  2   Weak Foot        16643 non-null  float64
#  3   Skill Moves      16643 non-null  float64
#  4   Work Rate        16643 non-null  object
#  5   Position         16643 non-null  object
#  6   Height           16643 non-null  object
#  7   Weight           16643 non-null  object
#  8   Crossing         16643 non-null  float64
#  9   Finishing        16643 non-null  float64
#  10  HeadingAccuracy  16643 non-null  float64
#  11  ShortPassing     16643 non-null  float64
#  12  Volleys          16643 non-null  float64
#  13  Dribbling        16643 non-null  float64
#  14  Curve            16643 non-null  float64
#  15  FKAccuracy       16643 non-null  float64
# ...

# %%
X=data.drop(['Name', 'Work Rate', 'Position', 'Height','Weight','Release Clause'],axis=1)
y=data['Position']
X,y
# Out:
# (        Age  Weak Foot  Skill Moves  Crossing  Finishing  HeadingAccuracy  \
#  ID
#  158023   31        4.0          4.0      84.0       95.0             70.0
#  20801    33        4.0          5.0      84.0       94.0             89.0
#  190871   26        5.0          5.0      79.0       87.0             62.0
#  193080   27        3.0          1.0      17.0       13.0             21.0
#  192985   27        5.0          4.0      93.0       82.0             55.0
#  ...     ...        ...          ...       ...        ...              ...
#  238813   19        2.0          2.0      34.0       38.0             40.0
#  243165   19        2.0          2.0      23.0       52.0             52.0
#  241638   16        3.0          2.0      25.0       40.0             46.0
#  246268   17        3.0          2.0      44.0       50.0             39.0
#  246269   16        3.0          2.0      41.0       34.0             46.0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(y)
y_enc = encoder.transform(y)
y, y_enc
# Out:
# (ID
#  158023     RF
#  20801      ST
#  190871     LW
#  193080     GK
#  192985    RCM
#           ...
#  238813     CM
#  243165     ST
#  241638     ST
#  246268     RW
#  246269     CM
#  Name: Position, Length: 16643, dtype: object,
#  array([21, 26, 14, ..., 26, 24,  4]))

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X,y_enc)

# %%
len(X_train), len(X_test)
# Out:
# (12482, 4161)

# %%
y_test
# Out:
# array([ 0, 17, 17, ..., 12, 17,  4])

# %%
model=RandomForestClassifier()
param_grid = {'n_estimators': [10,15], 'max_depth':[5,7]}
grid = GridSearchCV(model, param_grid,scoring='accuracy')
res=grid.fit(X_train,y_train)

#print(pd.DataFrame(encoder.inverse_transform(res.predict(X_test)), encoder.inverse_transform(y_test), columns=['predicted', 'actual']))

# %%
res.best_score_
# Out:
# 0.49503323860427384

# %%
col1 = encoder.inverse_transform(res.predict(X_test)).reshape(-1,1)
col2 = encoder.inverse_transform(y_test).reshape(-1,1)
dic = {'predicted': [col1], 'actual': [col2]}
df = pd.DataFrame.from_dict(dic)

# %%
df.head()
# Out:
#                                            predicted  \
# 0  [[CM], [LB], [LB], [CM], [ST], [CM], [RM], [CM...
#
#                                               actual
# 0  [[CAM], [RB], [RB], [LCM], [LW], [CM], [LM], [...

# %%
X.dropna(inplace=True)

# %%
X.count()
# Out:
# Age                16643
# Weak Foot          16643
# Skill Moves        16643
# Crossing           16643
# Finishing          16643
# HeadingAccuracy    16643
# ShortPassing       16643
# Volleys            16643
# Dribbling          16643
# Curve              16643
# FKAccuracy         16643
# LongPassing        16643
# BallControl        16643
# Acceleration       16643
# SprintSpeed        16643
# Agility            16643
# Reactions          16643
# Balance            16643
# ShotPower          16643
# Jumping            16643
# Stamina            16643
# Strength           16643
# LongShots          16643
# Aggression         16643
# Interceptions      16643
# Positioning        16643
# Vision             16643
# Penalties          16643
# Composure          16643
# Marking            16643
# StandingTackle     16643
# SlidingTackle      16643
# GKDiving           16643
# GKHandling         16643
# GKKicking          16643
# GKPositioning      16643
# GKReflexes         16643
# ...
